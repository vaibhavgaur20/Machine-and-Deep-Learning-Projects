# %% [markdown]
# https://github.com/Ebazhanov/linkedin-skill-assessments-quizzes/blob/main/python/python-quiz.md

# %% [markdown]
# # Q1. What is an abstract class?
# ## Ans: An abstract class exists only so that other "concrete" classes can inherit from the abstract class.
#
# #### Reason to have a abstract class
# - So that we can prevent user to make an object of an abstract class which in below example are Computer and Vehicle classes which are abstract classes and the user cannot create there objects.
# - It ensures that concrete classes(i.e. normal class) **must** define the abstract methods present in Abstract classes they inherited from.
#
# - In simple words abstract classes are a list of must have methods.

# %%
# We are using Abstract Base Class(ABC) 
# beacuse by default python doesn't support abstract class
from abc import ABC, abstractmethod

# %% [markdown]
# #### Expected an error

# %%
# Abstract class is a class that has at least 1 abstract method
class Computer(ABC):
    
    # Abstract method is a method which has a declaration but no defination
    @abstractmethod
    def process(self):
        pass
    
comp1 = Computer()
comp1.process()
class Laptop(Computer):
    pass
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/rd/v7072yzx5v7g477j17pc_qb80000gn/T/ipykernel_87427/1155986368.py in <module>
#       7         pass
#       8
# ----> 9 comp1 = Computer()
#      10 comp1.process()
#      11 class Laptop(Computer):
#
# TypeError: Can't instantiate abstract class Computer with abstract method process

# %% [markdown]
# #### Expected an Error

# %%
# Abstract class is a class that has at least 1 abstract method
class Computer(ABC):
    
    # Abstract method is a method which has a declaration but no defination
    @abstractmethod
    def process(self):
        pass

class Laptop(Computer):
    pass


comp1 = Laptop()
comp1.process()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# /var/folders/rd/v7072yzx5v7g477j17pc_qb80000gn/T/ipykernel_87427/4142036927.py in <module>
#      11
#      12
# ---> 13 comp1 = Laptop()
#      14 comp1.process()
#
# TypeError: Can't instantiate abstract class Laptop with abstract method process

# %%
# Abstract class is a class that has at least 1 abstract method
class Computer(ABC):
    
    # Abstract method is a method which has a declaration but no defination
    @abstractmethod
    def process(self):
        pass

class Laptop(Computer):
    def process(self):
        print("its running")


comp1 = Laptop()
comp1.process()
# Out:
# its running

# %%
class vehicle(ABC):
    
    @abstractmethod
    def move(self):
        pass
    @abstractmethod
    def brake(self):
        pass
    def headlights(self):
        pass
    
class MclarenF1(vehicle):
    def move(self):
        print("It moves")
    def brake(self):
        print("It brakes")

# %%
mc = MclarenF1()

mc.move()
mc.brake()
# Out:
# It moves
# It brakes

# %% [markdown]
# ### Q2. What happens when you use the build-in function any() on a list?
# ### Ans: The any() function returns True if any item in the list evaluates to True. Otherwise, it returns False.

# %%
lst = [0,1,0,0,0,0]
print(any(lst))

# It returns true because there is one true value and that is 1 among the entire list, and
# if there was no true value inside the list it would've returned false

# it can be read as if there is any True value in side the proviede list then return True,
# else return False
# Out:
# True

# %% [markdown]
# # Q3. What data structure does a binary tree degenerate to if it isn't balanced properly?
#
# ## Ans: Linked List
#
# ![Screenshot%202023-09-03%20at%205.17.42%20PM.png](attachment:Screenshot%202023-09-03%20at%205.17.42%20PM.png)

# %% [markdown]
# # Q4. What statement about static methods is true?
#
# ## ANS: Static methods serve mostly as utility methods or helper methods, since they can't access or modify a class's state.

# %% [markdown]
# ### class method
#
# an instance(self) will only make changes to that object but if use classmethod it makes changes to entire class and doesn't matter how many objects that you create the changes will appear in all

# %%
class Employee:
    
    num_of_emps =0 
    raise_amt = 1.04
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.email = first + '.' + last + '@email.com'
        self.pay = pay
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first,self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
    # instead of using instance variable self we use class(cls) as our first  argument
    # cls is the common convention
    @classmethod
    def set_raise_amt(cls,amount):
        cls.raise_amt = amount

emp_1 = Employee('Corey','Schafer', 50000)
emp_2 = Employee('Test','Employee',60000)

Employee.set_raise_amt(1.05)

print(Employee.raise_amt)
print(emp_1.raise_amt)
print(emp_2.raise_amt)
# Out:
# 1.05
# 1.05
# 1.05

# %% [markdown]
# ### Classmethod can also be used as alternative constructor
#
# Which means that if we receive information in different format (like string in the below case) we can use another constructor to break down the data according to our initial constructor to make it work

# %%
class Employee:
    
    num_of_emps =0 
    raise_amt = 1.04
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.email = first + '.' + last + '@email.com'
        self.pay = pay
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first,self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
    # instead of using instance variable self we use class(cls) as our first  argument
    # cls is the common convention
    @classmethod
    def set_raise_amt(cls,amount):
        cls.raise_amt = amount
####################################################
    @classmethod
    def from_string(cls,emp_str):
        first, last, pay = emp_str.split('-')
        return cls(first,last,pay)

emp_str_1 = 'John-Doe-70000'
emp_str_2 = 'Steve-Smith-30000'

new_emp_1 = Employee.from_string(emp_str_1)

print(new_emp_1.email)
print(new_emp_1.pay)
####################################################
# Out:
# John.Doe@email.com
# 70000

# %% [markdown]
# ### Static method
#
# is a method in class which seems relevent to be used but doesn't require any classmethod or instances in them
#
# A Give away in this situation is this always use static method if you know or see no use of instances or classmethod

# %%
class Employee:
    
    num_of_emps =0 
    raise_amt = 1.04
    
    def __init__(self, first, last, pay):
        self.first = first
        self.last = last
        self.email = first + '.' + last + '@email.com'
        self.pay = pay
        
        Employee.num_of_emps += 1
        
    def fullname(self):
        return '{} {}'.format(self.first,self.last)
    
    def apply_raise(self):
        self.pay = int(self.pay * self.raise_amt)
    # instead of using instance variable self we use class(cls) as our first  argument
    # cls is the common convention
    @classmethod
    def set_raise_amt(cls,amount):
        cls.raise_amt = amount

    @classmethod
    def from_string(cls,emp_str):
        first, last, pay = emp_str.split('-')
        return cls(first,last,pay)
####################################################
    @staticmethod
    def is_workday(day):
        if day.weekday() ==5 or day.weekday() ==6:
            return False
        return True

import datetime
my_date = datetime.date(2016, 7, 10) # which is a Sunday

print(Employee.is_workday(my_date))
####################################################
# Out:
# False

# %% [markdown]
# # Q5. What are attributes?
# ANS : Attributes are a way to hold data or describe a state for a class or an instance of a class.
#
# In simple words its a variable
#
# ``` Python
# class student: # class is attributes + methods
#     def __init__(self,age) # these are arguments or parameter
#     self.age = age # this is an attribute
#
#     def play(self): # this is a method
#         pass
# ```
#
# It's not the parameter of a function. Parameter of a function are know as arguments

# %% [markdown]
# # Q6. What is the term to describe this code?
# ```Python
# count, fruit, price = (2, 'apple', 3.5)
# ```
# - [ ] Tuple assignment
# - [x] Tuple unpacking

# %% [markdown]
# # Q7. What built-in list method would you use to remove items from a list?
#
# - [ ] .delete() method # it doesn't exist
# - [ ] pop(my_list) # it doesn't exist
# - [ ] del(my_list) # exists
# - [x] .pop() method # exists

# %%
li = [1,2,4]
print(li.pop())
print (li)
# Out:
# 4
# [1, 2]

# %% [markdown]
# # Q8. What is one of the most common use of Python's sys library?
#
# ANS: To capture command-line arguments given at a file's runtime.

# %% [markdown]
# # Q9. What is the correct way to write a doctest?
# - [ ] ```Python
#     def sum(a, b):
#     """
#     sum(4, 3)
#     7
#
#     sum(-4, 5)
#     1
#     """
#     return a + b
#     ```
#
# - [x] ``` Python
#     def sum(a, b):
#     """
#     >>> sum(4, 3)
#     7
#
#     >>> sum(-4, 5)
#     1
#     """
#     return a + b
# ```

# %% [markdown]
# ### Example

# %%
def square(x:float) -> float:
    """square the input
    >>> square(5)
    25
    >>> square(0)
    0
    """
    return x*x
import doctest
doctest.testmod()
# Out:
# TestResults(failed=0, attempted=4)

# %% [markdown]
# ### Go to terminal cd /Users/vaibhav/PycharmProjects/PythonApptitude
# ### run python3 dt.py -v
# ### OUTPUT
# ![Screenshot%202023-09-10%20at%208.18.51%20AM.png](attachment:Screenshot%202023-09-10%20at%208.18.51%20AM.png)

# %% [markdown]
# # Q12. What built-in Python data type is commonly used to represent a stack?
#
# ## ANS: list

# %% [markdown]
# # Q13. What would this expression return?
# ``` Python
# college_years = ['Freshman', 'Sophomore', 'Junior', 'Senior']
# return list(enumerate(college_years, 2019))
# ```
#
# - [ ] [('Freshman', 2019), ('Sophomore', 2020), ('Junior', 2021), ('Senior', 2022)]
# - [x] [(2019, 'Freshman'), (2020, 'Sophomore'), (2021, 'Junior'), (2022, 'Senior')]

# %% [markdown]
# # Q15. Which of these is NOT a characteristic of namedtuples?
# - You can assign a name to each of the namedtuple members and refer to them that way, similarly to how you would access keys in dictionary.
# - Each member of a namedtuple object can be indexed to directly, just like in a regular tuple.
# - namedtuples are just as memory efficient as regular tuples.
# - [x] No import is needed to use namedtuples because they are available in the standard library.

# %% [markdown]
# ### Why namedtuple instead of a dictionary ?
# - tuple are immutable, i.e. there value can't be changed
# - and in comparison to dict it is less messy and more organized and easy to change or add other keys
# - in dict there is a lot of typing

# %% [markdown]
# #### Example

# %%
from collections import namedtuple

Color = namedtuple('Color', ['red','green','blue'])

color = Color(55,155,255)

# Also; color = Color(red=55,green=155,blue=255)

print(color.red)
# Out:
# 55

# %% [markdown]
# # Q16. What is an instance method?
# - [x] Instance methods can modify the state of an instance or the state of its parent class.
# - [ ]  Instance methods hold data related to the instance.

# %% [markdown]
# Extras
# - instance methods are in which we use self
# - classmethod are in which we use cls and decorator @classmethod
# - accessor are those function that return values
# - mutators are those function that change values
# - classvariable

# %%
class Student:
    
    school = "BU" # classvariable: only accessed by classmethod
    
    def __init__(self,m1,m2):
        self.m1 = m1 # instance variable
        self.m2 = m2
        
    def avg(self): # instance method
        # print(school) ERROR
        return (self.m1 + self.m2)/2
    @classmethod
    def info(cls): # class method
        print(cls.school)
    
    @staticmethod
    def info2(): # static method
        print("this is info2")

# %%
s1  = Student(23,45)
s2 = Student(67,79)

print(s2.avg())
Student.info()
# Out:
# 73.0
# BU

# %% [markdown]
# # Q17. Which statement does NOT describe the OOP concept of encapsulation?
# - [ ]  It protects the data from outside interference. # OOP concept
# - [ ]  A parent class is encapsulated and no data from the parent class passes on to the child class. # OOP concept
# - [ ]  It keeps data and the methods that can manipulate that data in one place. # OOP concept
# - [x]  It only allows the data to be changed by methods. # Wrong, not an OOP concept

# %% [markdown]
# ![Screenshot%202023-09-11%20at%208.02.03%20AM.png](attachment:Screenshot%202023-09-11%20at%208.02.03%20AM.png)

# %%
class BU:
    
    school_name = "BU" # class variable
    
    def __init__(self,name):
        self.stu_name = name # instance variable
        
        
    def set_name(self,n_name): # mutator; instance method
        self.stu_name = n_name

# %%
s1 = BU("Vaibhav")

print(s1.stu_name)
s1.set_name("Gaur")
print(s1.stu_name)

s1.school_name = "Sherbrooke University"

print(s1.school_name)
# Out:
# Vaibhav
# Gaur
# Sherbrooke University

# %% [markdown]
# # Q19. What built-in Python data type is best suited for implementing a queue?
# - [ ] dictionary                     # n_dict = {key:value}
# - [ ] set                            # s_set = {9,"name",8.8}
# - [ ] None. You can only build a queue from scratch
# - [x] list

# %% [markdown]
# # Q21. What does the built-in map() function do?
# ## ANS:  It applies a function to each item in an iterable and returns the value of that function.

# %%
from functools import reduce

li = [1,2,3,4,5,6]

filtered = list(filter(lambda n : n%2==0,li))

print(filtered)

ma_li = list(map(lambda n : n+2, filtered))

print(ma_li)

su = reduce(lambda a,b : a+b, ma_li)
print(su)
# Out:
# [2, 4, 6]
# [4, 6, 8]
# 18

# %% [markdown]
# # Q23. What is the purpose of the pass statement in Python?
# - [ ] It is used to skip the yield statement of a generator and return a value of None.
# - [x] It is a null operation used mainly as a placeholder in function, classes etc.
# - [ ] It is used to skip the rest of a while or for loop and return to the start of the loop.

# %% [markdown]
# # Q24. What is the term used to describe items that may be passed into a function?
# - [x] arguments
# - [ ]  attributes

# %% [markdown]
# # Q28. Given the following three list, how would you create a new list that matches the desired output printed below?
#
# ```Python
# fruits = ['Apples', 'Oranges', 'Bananas']
# quantities = [5, 3, 4]
# prices = [1.50, 2.25, 0.89]
#
# #Desired output
# [('Apples', 5, 1.50),
# ('Oranges', 3, 2.25),
# ('Bananas', 4, 0.89)]
#
# ```
#
# - [x] ```Python
# i = 0
# output = []
# for fruit in fruits:
#     temp_qty = quantities[i]
#     temp_price = prices[i]
#     output.append((fruit, temp_qty, temp_price))
#     i += 1
# return output
# ```

# %% [markdown]
# #### Other best way of doing this

# %%
fruits = ['Apples', 'Oranges', 'Bananas']
quantities = [5, 3, 4]
prices = [1.50, 2.25, 0.89]

groceries = zip(fruits, quantities, prices)
print(list(groceries))
# Out:
# [('Apples', 5, 1.5), ('Oranges', 3, 2.25), ('Bananas', 4, 0.89)]

# %% [markdown]
# # Q29. What happens when you use the built-in function all() on a list?
# - [x] The all() function returns True if all items in the list evaluate to True. Otherwise, it returns False.

# %%
li = [1,1,0]

print(all(li))
# Out:
# False

# %% [markdown]
# # Q31. What is the algorithmic paradigm of quick sort?
#
# - [x] Divide and conquer

# %% [markdown]
# # Q32 What is runtime complexity of the list's built in .append() method ?
# - [x] O(1), also called constant time

# %% [markdown]
# # 33 What is the key difference between set and a list ?
# - [x] A set is an unordered collection of unique items. A list is an ordered collection of non-unique items

# %%
# Set are unordered , unchangeable and unindexed
se = {1,2,1,5,3,3,3,3,5}

print(se)
# Out:
# {1, 2, 3, 5}

# %% [markdown]
# # Q34 What is the definition of abstraction as applied to OOP Python?
# - [x] Abstraction mean that the implementation is hidden from the user, and only relevent data or information is shown.

# %% [markdown]
# # Q38 What does calling namedtuple on a collection type return ?
#
# - [x] a tuple subclass with iterable named feilds

# %% [markdown]
# # Q45 what is the proper way to write a list comprehension that represents all the keys in this dictionary?
# ```Python
# fruits = {'Apples':5, 'Oranges':3,'Bananas':4}
# ```
#
# - [ ] fruit_names = [x in fruits.kleys() for x]
# - [x] fruit_names = [x for x in fruits.keys()]

# %%
fruits = {'Apples':5, 'Oranges':3,'Bananas':4}

fruit_names =[x for x in fruits.keys()]
print(fruit_names)
# Out:
# ['Apples', 'Oranges', 'Bananas']

# %% [markdown]
# # Q 46 What is the purpose of self keyword when defining or calling methods on an instance of an object?
#
# - [ ] self refers to the class that was inherited from to create the object using self
# - [x] self refers to the instance whose method was called

# %% [markdown]
# # Q 47 What statement about the class method is true ?
#
# - [x] A class method can modify the state of the class, but it can't directly modify the state of an instance that inherits from that class.
#
# ###### "state of the class" generally refers to the attributes and properties of a class and its instance at a given point in time. It encompasses the value of instance variables, class variables, and any other data accociated with the class. The state o

# %% [markdown]
# # Q 48 What does it mean for a function to have linear runtime ?
#
# - [ ] You did not use very advanced computer programming concepts in your code.
# - [ ] The difficulty level your code is written at is not that high.
# - [ ] It will take your program less than half a second to run.
# - [x] The amount of time it takes for the function to complete grows lineraly as the input size increases

# %% [markdown]
# # Q 49 What is the proper way to define a function ?
#
# - [ ] def getMaxNum(list_of_nums):
# - [ ] func get_max_num(list_of_nums):
# - [ ] func getMaxNum(list_of_nums):
# - [x] def get_max_num(list_of nums):

# %% [markdown]
# # Q 51 Describe the functionality of a deque? (deque is double ended queue)
#
# - [x] a deque adds items at either or both ends and removes items at either or both ends
# - [ ] a deque adds items to either or both sides but only removes items from the top
# - [ ] A deque adds items to one side and removes items from the other side

# %% [markdown]
# ![image.png](attachment:image.png)

# %% [markdown]
# # Q 52 What is the correct syntax for creating a variable that is bound to a set?
# - [x] ` my_set = {0,'apple',3.5} `
# - [ ] my_set = to_set(0,'apple',3.5)
# - [ ] my_set = (0,'apple',3.5).to_set()
# - [ ] my_set = (0,'apple',3.5).set()

# %% [markdown]
# # 54 Which of the following is TRUE About how numeric data would be organized in a Binary Search Tree ?
# - [x] For any given node in binary search tree, the value of the node is greater than all the values in the node's left subtree and less than the ones in its right subtree.

# %% [markdown]
# ![image-2.png](attachment:image-2.png)

# %% [markdown]
# # Q 58 What would happen if you did not alter the state of the element that an algorithm is operating on recursively?
# - [ ] You do not have to alter the state of the element the algorithm is recursing on.
# - [ ] You would eventually get a KeyError when the recursive portion of the code ran out of items to recurse on.
# - [x] You would get a RuntimeError:maximum recursion depth exvceeded

# %% [markdown]
# # Q 59 What is the runtime complexity of searching for an item in a binary tree ?
# - [x] The runtime for searching in a binary search tree is generally O(h), where h is the height of the binary tree

# %% [markdown]
# # Q 60 Why would you use mixin ?
# - [x] if you have many classes that all need to have the same funtionality, you'd use a mixin to define that functionality
# ![Screenshot%202023-12-20%20at%208.25.51%E2%80%AFAM.png](attachment:Screenshot%202023-12-20%20at%208.25.51%E2%80%AFAM.png)
# https://www.youtube.com/watch?v=zNPaqZUTzs0

# %%
# framework code (or you can say library)
class A:
    total = 342.33
    
class B(A):
    pass
class C(A):
    pass

# our code 
class M:                  # mixin class
    def print_total(self):
        print(self.total)
        
class D(B, M):
    pass
class E(C,M):
    pass

e = E()

e.print_total()
# Out:
# 342.33

# %% [markdown]
# # Q 64 Why is it considered good practice to open a file from within a Python script by using with keyword ?
#
# It is a good practice to use the 'with' keyword when dealing with file objects. The advantage is that the file is properly closed after its suite finishes, even if an exception is raised at some point. Using with is also much shorter than writing equivalent try-finally blocks:

# %%
f = open('xyz','w',encoding="utf-8")
with open('xyz', encoding="utf-8") as f:
    read_data = f.read()
    
# We can check that the file has been automatically closed.
f.closed
# Out:
# True
